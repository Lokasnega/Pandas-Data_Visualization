# %% [markdown]
# ###### Assessment

# %% [markdown]
# ###### I am going to provide two .csv files , you are supposed to work on them and have to provide solutions to the following problems

# %% [markdown]
# ###### import necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ###### merge those two csv files (after getting as dataframes, get them as a single dataframe)

# %%
df1 = pd.read_csv("/content/college_1.csv")
df1
# Out:
#               Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0        A.Dharani    82.0   20.0              24500           24500
# 1      V.JEEVITHA     82.0   20.0              21740           21740
# 2      HEMAVATHI.R   100.0  100.0              19680           19680
# 3      Mugunthan S   100.0   47.0              10610           10610
# 4      Sathammai.S   100.0    8.0               8980            8980
# ..             ...     ...    ...                ...             ...
# 79    KarthikeyanS    45.0    0.0                  0               0
# 80        BARATH.P    29.0    0.0                  0               0
# 81   N.Ajith kumar    82.0    0.0                  0               0
# 82    mohamed nabi     0.0    0.0                  0               0
# 83  yaser ahamed.A     0.0   27.0                  0               0
#
#                                 Department  Rising
# 0         Computer Science and Engineering       0
# ...

# %%
df2 = pd.read_csv('/content/college_2.csv')
df2
# Out:
#                       Name  python  python_en  mysql  computational_thinking  \
# 0            ASHOK KUMAR K     100          0     31                       9
# 1                  Chandru       0         20      0                       0
# 2        Ganesh Ramkumar R      -1         55     24                       6
# 3          Bodipudi Harini      -1          0     35                      -1
# 4                VIINU V P      -1        100     24                      -1
# 5               Poojitha Y       0         78     35                       0
# 6   Gowtham Chandrasekaran      -1          0      0                       3
# 7                Gowtham R      -1         60      4                       6
# 8                 shifak N      58          0      0                       0
# 9                  Balaji       -1        100     20                       0
# 10                Rushitha      -1         15     62                       9
# ...

# %%
df = pd.concat([df1,df2])
df
# Out:
#              Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0       A.Dharani    82.0   20.0              24500           24500
# 1     V.JEEVITHA     82.0   20.0              21740           21740
# 2     HEMAVATHI.R   100.0  100.0              19680           19680
# 3     Mugunthan S   100.0   47.0              10610           10610
# 4     Sathammai.S   100.0    8.0               8980            8980
# ..            ...     ...    ...                ...             ...
# 30  praveen raj j    24.0    0.0               2380            2380
# 31     AMARNATH D    -1.0   12.0               1890            1890
# 32           bala    32.0    0.0               1720            1720
# 33           XY Z    -1.0   -1.0                  0               0
# 34      Hariharan    -1.0   -1.0                  0               0
#
#                                    Department  Rising  python_en  \
# 0            Computer Science and Engineering       0        NaN
# ...

# %% [markdown]
# ###### Take each csv file , split that csv file into multiple categories (example csv files are added in the repo)

# %% [markdown]
# ###### consider if the codekata score exceeds 15000 points(present week) then make a csv on those observations as Exceeded expectations.csv

# %%
#codekata score exceeds 15000 points
data1 = df[df["CodeKata Score"] > 15000]
data1
# Out:
#             Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0      A.Dharani    82.0   20.0              24500           24500
# 1    V.JEEVITHA     82.0   20.0              21740           21740
# 2    HEMAVATHI.R   100.0  100.0              19680           19680
# 0  ASHOK KUMAR K   100.0   31.0              19400           19400
#
#                                Department  Rising  python_en  \
# 0        Computer Science and Engineering       0        NaN
# 1        Computer Science and Engineering       0        NaN
# 2        Computer Science and Engineering       0        NaN
# 0  Electronics and Electrical Engineering       0        0.0
#
#    computational_thinking
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 0                     9.0

# %%
data1.to_csv('/content/Exceeded expectations.csv')

# %% [markdown]
# ###### if  10000<codekata score<15000   (Reached_expectations.csv)

# %%
data2 = df[(df["CodeKata Score"] > 10000) & (df["CodeKata Score"] < 15000)]
data2
# Out:
#                 Name  python  mysql  Previous Geekions  CodeKata Score  \
# 3        Mugunthan S   100.0   47.0              10610           10610
# 1            Chandru     0.0    0.0              14150           14490
# 2  Ganesh Ramkumar R    -1.0   24.0               8790           10790
# 3    Bodipudi Harini    -1.0   35.0              10040           10040
#
#                                   Department  Rising  python_en  \
# 3           Computer Science and Engineering       0        NaN
# 1           Computer Science and Engineering     340       20.0
# 2           Computer Science and Engineering    2000       55.0
# 3  Electronics and Communication Engineering       0        0.0
#
#    computational_thinking
# 3                     NaN
# 1                     0.0
# 2                     6.0
# 3                    -1.0

# %%
data2.to_csv('/content/Reached_expectations.csv')

# %% [markdown]
# ###### if  7000<codekata score<10000   (Needs_Improvement.csv)

# %%
data3 = df[(df["CodeKata Score"] > 7000) & (df["CodeKata Score"] < 10000)]
data3
# Out:
#                       Name  python  mysql  Previous Geekions  CodeKata Score  \
# 4              Sathammai.S   100.0    8.0               8980            8980
# 5             NIVEESHWAR S   100.0    0.0               8200            8200
# 6            KALAIARASAN K    85.0   47.0               7750            7880
# 7     MOHAMED ZUBAIR AHMED    82.0    4.0               7020            7020
# 4                VIINU V P    -1.0   24.0               9150            9150
# 5               Poojitha Y     0.0   35.0               7210            8970
# 6   Gowtham Chandrasekaran    -1.0    0.0               7250            8950
# 7                Gowtham R    -1.0    4.0               8650            8650
# 8                 shifak N    58.0    0.0               5180            8320
# 9                  Balaji     -1.0   20.0               6170            8160
# 10                Rushitha    -1.0   62.0               7470            8090
# ...

# %%
data3.to_csv('/content/Needs_Improvement.csv')

# %% [markdown]
# ###### if  codekate score < 7000        (Unsatisfactory.csv)

# %%
data4 = df[df["CodeKata Score"] < 7000]
data4
# Out:
#                Name  python  mysql  Previous Geekions  CodeKata Score  \
# 8        J.SUGANTHI    27.0  50.00               5860            5860
# 9      thamizhpaana    29.0   0.00               5500            5500
# 10  Iyappan Samiraj    50.0  24.00               5400            5400
# 11     Ponniyamma.R   100.0  11.25               5380            5380
# 12        SABAPATHI   100.0   0.00               5280            5280
# ..              ...     ...    ...                ...             ...
# 30    praveen raj j    24.0   0.00               2380            2380
# 31       AMARNATH D    -1.0  12.00               1890            1890
# 32             bala    32.0   0.00               1720            1720
# 33             XY Z    -1.0  -1.00                  0               0
# 34        Hariharan    -1.0  -1.00                  0               0
#
#                                    Department  Rising  python_en  \
# ...

# %%
data4.to_csv('/content/Unsatisfactory.csv')

# %% [markdown]
# ###### Average of previous week geekions vs this week geekions (i.e Previous Geekions vs CodeKata Score)

# %%
avg = df.iloc[:, 3:5]
avg.mean()
# Out:
# Previous Geekions    3842.352941
# CodeKata Score       4051.764706
# dtype: float64

# %% [markdown]
# ###### No of students participated

# %%
len(df)
# Out:
# 119

# %% [markdown]
# ###### #Average completion of python course or my_sql or python english or computational thinking

# %%
df['mean'] = df.iloc[:,[1,2,7,8]].mean(axis =1)
df.drop(["Previous Geekions","CodeKata Score",'Department','Rising'],axis = "columns")
# Out:
#              Name  python  mysql  python_en  computational_thinking    mean
# 0       A.Dharani    82.0   20.0        NaN                     NaN   51.00
# 1     V.JEEVITHA     82.0   20.0        NaN                     NaN   51.00
# 2     HEMAVATHI.R   100.0  100.0        NaN                     NaN  100.00
# 3     Mugunthan S   100.0   47.0        NaN                     NaN   73.50
# 4     Sathammai.S   100.0    8.0        NaN                     NaN   54.00
# ..            ...     ...    ...        ...                     ...     ...
# 30  praveen raj j    24.0    0.0       -1.0                     0.0    5.75
# 31     AMARNATH D    -1.0   12.0       52.0                    -1.0   15.50
# 32           bala    32.0    0.0       49.0                    -1.0   20.00
# 33           XY Z    -1.0   -1.0       20.0                    -1.0    4.25
# 34      Hariharan    -1.0   -1.0       -1.0                     0.0   -0.75
#
# [119 rows x 6 columns]

# %%
avg = df.loc[:,["python","mysql","python_en","computational_thinking"]]
avg.mean()
# Out:
# python                    54.352941
# mysql                     23.500000
# python_en                 29.657143
# computational_thinking     2.200000
# dtype: float64

# %% [markdown]
# ###### rising star of the week (top 3 candidate who performed well in that particular week)

# %%
df.drop(["Previous Geekions",'Department','Rising',
         'python','mysql','python_en','computational_thinking','mean'],axis = "columns").sort_values(by="CodeKata Score",ascending = False).head(3)
# Out:
#           Name  CodeKata Score
# 0    A.Dharani           24500
# 1  V.JEEVITHA            21740
# 2  HEMAVATHI.R           19680

# %% [markdown]
# ###### Shining stars of the week (top 3 candidates who has highest geekions)

# %%
df['Total_Geekions'] = df['Previous Geekions'] + df['CodeKata Score']
df.drop(["Previous Geekions","CodeKata Score",'Department','Rising',
         'python','mysql','python_en','computational_thinking','mean'],axis = "columns").sort_values(by="Total_Geekions",ascending = False).head(3)
# Out:
#           Name  Total_Geekions
# 0    A.Dharani           49000
# 1  V.JEEVITHA            43480
# 2  HEMAVATHI.R           39360

# %% [markdown]
# ###### Department wise codekata performence (pie chart)

# %%
import matplotlib.pyplot as plt
df.groupby(['Department']).sum().plot(kind='pie', y='Total_Geekions',autopct='%1.0f%%', shadow = True, startangle = 140)

# %% [markdown]
# ###### Department wise toppers (horizantal bar graph or any visual representations of your choice)

# %%
df
# Out:
#              Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0       A.Dharani    82.0   20.0              24500           24500
# 1     V.JEEVITHA     82.0   20.0              21740           21740
# 2     HEMAVATHI.R   100.0  100.0              19680           19680
# 3     Mugunthan S   100.0   47.0              10610           10610
# 4     Sathammai.S   100.0    8.0               8980            8980
# ..            ...     ...    ...                ...             ...
# 30  praveen raj j    24.0    0.0               2380            2380
# 31     AMARNATH D    -1.0   12.0               1890            1890
# 32           bala    32.0    0.0               1720            1720
# 33           XY Z    -1.0   -1.0                  0               0
# 34      Hariharan    -1.0   -1.0                  0               0
#
#                                    Department  Rising  python_en  \
# 0            Computer Science and Engineering       0        NaN
# ...

# %%
top = df.groupby('Department', group_keys=True).apply(lambda x: x.nlargest(3, "Total_Geekions"))
top
# Out:
#                                                          Name  python  mysql  \
# Department
# Computer Science and Engineering          0         A.Dharani    82.0   20.0
#                                           1       V.JEEVITHA     82.0   20.0
#                                           2       HEMAVATHI.R   100.0  100.0
# Electronics and Communication Engineering 3   Bodipudi Harini    -1.0   35.0
#                                           7         Gowtham R    -1.0    4.0
#                                           6     KALAIARASAN K    85.0   47.0
# Electronics and Electrical Engineering    0     ASHOK KUMAR K   100.0   31.0
#                                           4         VIINU V P    -1.0   24.0
#                                           12         JPradhap   100.0    0.0
#
#                                               Previous Geekions  \
# Department
# Computer Science and Engineering          0               24500
# ...

# %%
# barplot code
import seaborn as sns

# %%
sns.barplot(y = 'Department', x = 'Total_Geekions', data =top)

# %%
# plotting graph
top.plot(x="Department", y=["Name", "Total_Geekions"], kind="bar")
